# %% [markdown]
# <a href="https://colab.research.google.com/github/maryam98712333333333/mining-maryam-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")

# %%
dataTrain = pd.read_csv('gold price Maryam.csv')
dataTrain.head()
# Out:
#          Date        Open        High         Low  Close    Volume  EU_Trend  \
# 0  15/12/2011  154.740005  154.949997  151.710007   OPEN  21521900         1
# 1  16/12/2011  154.309998  155.369995  153.899994  CLOSE  18124300         1
# 2  19/12/2011  155.479996  155.860001  154.360001   OPEN  12547200         0
# 3  20/12/2011  156.820007  157.429993  156.580002   OPEN   9136300         1
# 4  21/12/2011  156.979996  157.529999  156.130005   OPEN  11996100         0
#
#     Price
# 0  105.09
# 1  103.35
# 2  103.64
# 3  106.73
# 4  107.71

# %%
type(dataTrain)


dataTrain.shape
# Out:
# (1718, 8)

# %%
dataTrain.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close       10
# Volume       0
# EU_Trend     0
# Price        0
# dtype: int64

# %%
dataTrain = dataTrain.dropna()

# %%
dataTrain.isnull().sum()
# Out:
# Date        0
# Open        0
# High        0
# Low         0
# Close       0
# Volume      0
# EU_Trend    0
# Price       0
# dtype: int64

# %%
dataTrain.shape
# Out:
# (1708, 8)

# %%
dataTrain.dtypes
# Out:
# Date         object
# Open        float64
# High        float64
# Low         float64
# Close        object
# Volume        int64
# EU_Trend      int64
# Price       float64
# dtype: object

# %%
plt.figure(figsize=(10,6))
corr = dataTrain.corr()

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %%
dataTrain.describe()
# Out:
#               Open         High          Low        Volume     EU_Trend  \
# count  1708.000000  1708.000000  1708.000000  1.708000e+03  1708.000000
# mean    127.454256   127.984350   126.908003  8.444742e+06     0.494731
# std      17.494263    17.600236    17.363481  4.929047e+06     0.500119
# min     100.919998   100.989998   100.230003  1.501600e+06     0.000000
# 25%     116.269997   116.627499   115.822502  5.390525e+06     0.000000
# 50%     121.989998   122.380001   121.475002  7.483900e+06     0.000000
# 75%     128.467506   129.147499   127.892500  1.019288e+07     1.000000
# max     173.199997   174.070007   172.919998  9.380420e+07     1.000000
#
#              Price
# count  1708.000000
# mean     77.638987
# std      27.423974
# min      27.880000
# 25%      52.100000
# 50%      70.345000
# 75%     107.760000
# max     126.220000

# %%
dataTrain['Price'].plot(kind = 'hist', bins = 5, edgecolor='Red') # 5 bins are used
plt.xlabel('Price')
plt.ylabel('Volume')
plt.title('EU_Trend')
plt.show()

# %%
dataTrain.describe(include = 'object')
# Out:
#               Date Close
# count         1708  1708
# unique        1708     2
# top     15/12/2011  OPEN
# freq             1   927

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Volume", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Volume', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Volume'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.08201457135135441  with a P-value of P = 0.0006919982803941868

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="High", y="Price", data= dataTrain)

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9999999999999998  with a P-value of P = 0.0

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="EU_Trend", y="Price", data= dataTrain)
# Out:
# <Axes: xlabel='EU_Trend', ylabel='Price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['Volume'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.08201457135135441  with a P-value of P = 0.0006919982803941868

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Open", y="Price", data= dataTrain)
# Out:
# <Axes: xlabel='Open', ylabel='Price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['Price'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9999999999999998  with a P-value of P = 0.0

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Low", y="Price", data= dataTrain)

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9999999999999998  with a P-value of P = 0.0

# %%
sns.boxplot(x="Volume", y="Price", data= dataTrain)
# Out:
# <Axes: xlabel='Volume', ylabel='Price'>

# %%
sns.boxplot(x="Open", y="Price", data= dataTrain)
# Out:
# <Axes: xlabel='Open', ylabel='Price'>

# %%
sns.boxplot(x="High", y="Price", data= dataTrain)
# Out:
# <Axes: xlabel='High', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Low", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Low', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Close", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Close', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="EU_Trend", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='EU_Trend', ylabel='Price'>

# %%
dataTrain.drop(['Date', 'Close' ,'High' , 'Open' , 'Low'], axis = 1, inplace = True)
# Out:
# Date         object
# Open        float64
# High        float64
# Low         float64
# Close        object
# Volume        int64
# EU_Trend      int64
# Price       float64
# dtype: object

# %%
dataTrain.drop(['Date', 'Close' ,'High' , 'Open' , 'Low'], axis = 1, inplace = True)

# %%
dataTrain.shape
# Out:
# (1708, 3)

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataTrain.EU_Trend = labelencoder.fit_transform(dataTrain.EU_Trend)
dataTrain.Volume = labelencoder.fit_transform(dataTrain.Volume)

# %%
dataTrain.head(10)
# Out:
#    Volume  EU_Trend   Price
# 0    1671         1  105.09
# 1    1645         1  103.35
# 2    1470         0  103.64
# 3    1146         1  106.73
# 4    1435         0  107.71
# 5    1227         1  107.89
# 6      83         0  107.96
# 7     319         1  109.27
# 8    1614         0  107.56
# 9    1663         1  108.01

# %%
import scipy.stats as stats
dataTrain= stats.zscore(dataTrain)

# %%
from sklearn.model_selection import train_test_split
x = dataTrain.drop(['Price'], axis=1)
y = dataTrain['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
dataTrain.shape
# Out:
# (1708, 3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1195, 2)
# (513, 2)
# (1195,)
# (513,)

# %%
x_train.head()
# Out:
#        Volume  EU_Trend
# 7   -1.081733  1.010595
# 56   1.403795 -0.989516
# 339  1.669517 -0.989516
# 690 -0.981576 -0.989516
# 227 -0.321357  1.010595

# %%
y_train.head()
# Out:
# 7      1.153745
# 56     1.763244
# 339    0.984865
# 690    0.099979
# 227    1.242380
# Name: Price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model_mlr = model.fit(x_train,y_train)

# %%
y_pred1 = model_mlr.predict(x_test)

# %%
y_pred1[0]
# Out:
# -0.16713099807127735

# %%
mse1 = mean_squared_error(y_test, y_pred1)
print('The mean square error for Multiple Linear Regression: ', mse1)
# Out:
# The mean square error for Multiple Linear Regression:  1.0452634603729842

# %%
mae1= mean_absolute_error(y_test, y_pred1)
print('The mean absolute error for Multiple Linear Regression: ',mae1)
# Out:
# The mean absolute error for Multiple Linear Regression:  0.9324148658828549

# %%
rf = RandomForestRegressor()
model_rf = rf.fit(x_train,y_train)

# %%
y_pred2 = model_rf.predict(x_test)

# %%
mse2 = mean_squared_error(y_test, y_pred1)
print('The mean square error for Multiple Linear Regression: ',mae2)
# Out:
# The mean square error for Multiple Linear Regression:  0.9678705611792213

# %%
mae2= mean_absolute_error(y_test, y_pred2)
print('The mean absolute error of price and predicted value is: ', mae2)
# Out:
# The mean absolute error of price and predicted value is:  0.9678705611792213

# %%
LassoModel = Lasso()
model_lm = LassoModel.fit(x_train,y_train)

# %%
y_pred3 = model_lm.predict(x_test)

# %%
mae3= mean_absolute_error(y_test, y_pred3)
print('The mean absolute error of price and predicted value is: ', mae3)
# Out:
# The mean absolute error of price and predicted value is:  0.9428512702784064

# %%
mse3 = mean_squared_error(y_test, y_pred3)
print('The mean square error of price and predicted value is: ', mse3)
# Out:
# The mean square error of price and predicted value is:  1.0534189079837915

# %%
scores = [('MLR', mae1),
          ('Random Forest', mae2),
          ('LASSO', mae3)
         ]

# %%
mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
mae
# Out:
#            Model  MAE Score
# 0            MLR   0.932415
# 1  Random Forest   0.967871
# 2          LASSO   0.942851

# %%
mae.sort_values(by=(['MAE Score']), ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(10,7))
sns.barplot(x = mae['Model'], y=mae['MAE Score'], ax = axe)
axe.set_xlabel('Model', size=20)
axe.set_ylabel('Mean Absolute Error', size=20)

plt.show()
